# %% [markdown]
# <a href="https://colab.research.google.com/github/furhuruhun/PrakSatuII4012/blob/RAG/qa_chatbot_18223004_18223098.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Praktikum 1: Chatbot II4012 Inteligensi Artifisial untuk Bisnis**
#
# **Tanggal**: 5 Maret 2026
#
# ---
#
# **Anggota Kelompok:**
# *   Muhammad Farhan (18223004)
# *   Kenlyn Tesalonika W (18223098)
#
# **Topik Chatbot:**
#
# Peraturan Kemahasiswaan ITB 2022.
#
# **Tujuan:**
#
# Implementasi dan analisis perbandingan chatbot berbasis aturan (rule-based) dan generatif.

# %% [markdown]
# (Kredit: Asisten II4012)
#
# Pada bagian ini, Anda akan mempelajari beberapa contoh tools untuk membuat chatbot sederhana baik berbasis rule atau berbasis model generative.

# %% [markdown]
# ## Rule-based Chatbot using regex
#
# Referensi tambahan:
# 1. https://www.w3schools.com/python/python_regex.asp
# 2. https://docs.python.org/3/library/re.html

# %%
import re

ANS_BEASISWA = """\
Beasiswa bertujuan menumbuhkan potensi dan daya juang (Pasal 3).
Jenisnya terdiri dari Beasiswa Prestasi dan Beasiswa Ekonomi (Pasal 4).
Mahasiswa penerima beasiswa sarjana berkontribusi melalui kerja paruh waktu maksimal 2 jam/hari atau 10 jam/pekan (Pasal 5)."""

ANS_ASRAMA = """\
Asrama Mahasiswa ITB dapat dihuni selama-lamanya 1 tahun (Pasal 6).
Layanan asrama diprioritaskan untuk mahasiswa Tahap Persiapan Bersama (TPB).
Penghuni wajib mengikuti aturan tata tertib dan kegiatan pengembangan karakter (Pasal 6)."""

ANS_KESEHATAN = """\
Layanan kesehatan membantu mahasiswa menjaga kesehatan psikis dan mental selama masa studi (Pasal 7).
ITB memberikan subsidi biaya rawat jalan yang nilainya ditentukan oleh Unit Kerja layanan kesehatan (Pasal 7)."""

ANS_KONSELING = """\
Layanan bimbingan dan konseling mencakup bimbingan karir, proses belajar, hingga konseling masalah pribadi atau sosial (Pasal 8) .
Layanan ini didasarkan pada asas kerahasiaan dan kesukarelaan (Pasal 8)."""

ANS_DISABILITAS = """\
Layanan disabilitas bertujuan agar mahasiswa memaksimalkan potensi dan lulus dengan baik (Pasal 9).
ITB menyediakan serta meminjamkan sarana prasarana khusus bagi mahasiswa penyandang disabilitas (Pasal 9)"""

ANS_KARAKTER = """\
Pengembangan karakter bertujuan menanamkan jujur, kerja sama tim, dan kepekaan sosial (Pasal 10).
Kegiatannya meliputi Studium Generale, latihan kepemimpinan, hingga pengabdian masyarakat (Pasal 10)."""

ANS_KEWIRAUSAHAAN = """\
Pengembangan kewirausahaan mencakup pelatihan, perekrutan, dan kesempatan magang (Pasal 11).
Program ini dijalankan melalui jejaring kerja sama dengan industri dan pemerintah (Pasal 11)."""

ANS_IZIN_KEGIATAN = """\
Izin kegiatan tingkat ITB diberikan oleh Unit Kerja Kemahasiswaan, sedangkan tingkat Prodi/Fakultas diberikan oleh Dekan (Pasal 14).
Kegiatan harus sesuai harkat pendidikan dan mendapat persetujuan dosen pembimbing (Pasal 15)."""

ANS_ORGANISASI = """\
Organisasi kemahasiswaan tidak boleh berafiliasi dengan partai politik atau organisasi luar ITB (Pasal 17).
Jenisnya meliputi Kabinet KM ITB (terpusat), UKM (institut), serta Himpunan Mahasiswa (Fakultas/Prodi) (Pasal 18) ."""

ANS_MAPRES = """\
Syarat Mahasiswa Berprestasi (Mapres) tingkat Sarjana: Telah menempuh 6 semester, usia maksimal 22 tahun, memiliki prestasi internasional/nasional, serta IP tinggi (Pasal 27)."""

ANS_GANESHA = """\
Penghargaan Ganesha terdiri atas 4 kategori (Pasal 28) :
1. Ganesha Perkasa (Olahraga)
2. Ganesha Rasa (Seni/Budaya)
3. Ganesha Karsa (Ilmiah/Sosial)
4. Ganesha Karya (Inovatif)"""

rules = [
    (re.compile(r"(?=.*(beasiswa|bantuan biaya|dana))(?=.*(apa|gimana|cara|syarat|tujuan|tugas))", re.I), ANS_BEASISWA),
    (re.compile(r"(?=.*(asrama|tinggal|huni))(?=.*(berapa lama|durasi|siapa|tpb|syarat))", re.I), ANS_ASRAMA),
    (re.compile(r"(?=.*(sehat|sakit|dokter|rawat|medis))(?=.*(apa|biaya|subsidi|gimana))", re.I), ANS_KESEHATAN),
    (re.compile(r"(?=.*(konseling|curhat|psikolog|mental))(?=.*(apa|maksud|definisi|tujuan|gimana))", re.I), ANS_KONSELING),
    (re.compile(r"(?=.*(disabilitas|difabel|berkebutuhan khusus))(?=.*(apa|fasilitas|layanan|bantuan))", re.I), ANS_DISABILITAS),
    (re.compile(r"(?=.*(karakter|studium generale|sg|latihan pimpinan))(?=.*(apa|tujuan|kegiatan))", re.I), ANS_KARAKTER),
    (re.compile(r"(?=.*(wirausaha|bisnis|startup|magang))(?=.*(apa|gimana|program|kerjasama))", re.I), ANS_KEWIRAUSAHAAN),
    (re.compile(r"(?=.*(izin|boleh|prosedur))(?=.*(kegiatan|acara|event|prodi|fakultas))", re.I), ANS_IZIN_KEGIATAN),
    (re.compile(r"(?=.*(organisasi|himpunan|ukm|km|kabinet))(?=.*(jenis|macam|apa|larangan|politik))", re.I), ANS_ORGANISASI),
    (re.compile(r"(?=.*(mapres|mahasiswa berprestasi))(?=.*(apa|syarat|kriteria|daftar|siapa))", re.I), ANS_MAPRES),
    (re.compile(r"(?=.*(ganesha|penghargaan))(?=.*(apa|jenis|kategori|perkasa|rasa|karsa))", re.I), ANS_GANESHA),
]

fallback = "Maaf, Coba tanya hal lain kak, entah beasiswa, asrama, atau organisasi gitu."

def clean_text(text: str) -> str:
    """Bersihin input user: lowercase, hapus tanda baca, dan buang filler."""
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    fillers = r'\b(sih|itu|dong|lah|kah|ya|ini|itu|banget|deh|an)\b'
    text = re.sub(fillers, '', text)
    text = " ".join(text.split())
    return text

def find_answer(text: str) -> str:
    cleaned = clean_text(text)
    for pat, ans in rules:
        if pat.match(cleaned):
            return ans
    return fallback


if __name__ == "__main__":
    print(" AI Pengganti CS peraturan akademik. Ketik 'exit', 'quit', 'keluar' untuk keluar.")
    while True:
        user = input("\nYou: ").strip()
        if not user or user.lower() in ("exit", "quit", "keluar"):
            print("AI: Until next time!")
            break
        print("AI:", find_answer(user))
# Out:
#  AI Pengganti CS peraturan akademik. Ketik 'exit', 'quit', 'keluar' untuk keluar.
#
# You: duh gw mau izin kegiatan nih
# AI: Izin kegiatan tingkat ITB diberikan oleh Unit Kerja Kemahasiswaan, sedangkan tingkat Prodi/Fakultas diberikan oleh Dekan (Pasal 14).
# Kegiatan harus sesuai harkat pendidikan dan mendapat persetujuan dosen pembimbing (Pasal 15).
#
# You: syarat mapres teh naon ya
# AI: Syarat Mahasiswa Berprestasi (Mapres) tingkat Sarjana: Telah menempuh 6 semester, usia maksimal 22 tahun, memiliki prestasi internasional/nasional, serta IP tinggi (Pasal 27) [cite: 357-361].
#
# You: quit
# AI: Until next time!

# %% [markdown]
# ## Rule-based Chatbot using NLTK
# Sumber: https://www.analyticsvidhya.com/blog/2021/07/build-a-simple-chatbot-using-python-and-nltk/

# %%
import nltk
from nltk.chat.util import Chat, reflections

# Define some patterns and responses
patterns = [
    [
        r"hi|hey|hello|halo|hei",
        ["Halo, ada yang bisa aku bantu?", "Halo, aku siap menjawab pertanyaanmu terkait peraturan kemahasiswaan di ITB.",]
    ],
    [
        r".*(nama|nama kamu).*",
        ["Nama aku adalah Chatbot Peraturan Kemahasiswaan ITB.", "Aku Chatbot Peraturan Kemahasiswaan ITB, asisten virtual untuk membantu kamu mendapatkan informasi peraturan kemahasiswaan di ITB.",]
    ],
    [
        r".*(layanan|layanan kemahasiswaan).*",
        ["Berikut adalah jenis layanan kemahasiswaan yang ada di ITB:\n"
        "a. Penyaluran Beasiswa dan/atau Bantuan Biaya Pendidikan;\n"
        "b. Asrarna Mahasiswa;\n"
        "c. Program Layanan Kesehatan Mahasiswa;\n"
        "d. Bimbingan dan Konseling;\n"
        "e. Pelatihan dan Pengembangan Karakter;\n"
        "f. Pengembangan Keprofesian dan Kewirausahaan Mahasiswa;\n"
        "g. Layanan Kegiatan Kemahasiswaan;\n"
        "h. Layanan bagi mahasiswa penyandang disabilitas.",]
    ],
    [
        r".*syarat.*beasiswa.*",
        ["Berikut adalah syarat bagi penerima beasiswa:\n"
        "- Beasiswa Prestasi: mahasiswa yang memiliki prestasi atau potensl akademik yang balk yang dlantaranya ditunjukkan oleh Indeks Prestasi akademik yang baik dan/atau capaian dalam bidang ko-kurikuler atau ekstra-kurikuler.\n"
        "- Beasiswa Ekonomi: mahasiswa yang memiliki keterbatasan kernampuan ekonomi dengan tetap mempertimbangkan prestasi atau potensi akademik yang bersangkutan, dan/atau syarat lain yang diatur oleh Unit Kerja 1TB yang menanganl urusan kernahaslswaan.\n",]
    ],
    [
        r".*beasiswa.*",
        ["Terdapat 2 jenis beasiswa yang dapat diberikan oleh ITB yakni beasiswa prestasi dan beasiswa ekonomi, beasiswa tersebut dapat mencakup bantuan biaya kuliah, bantuan biaya tugas akhir, bantuan biaya hidup dan/atau bentuk lain untuk membantu mahasiswa dalam mengikuti dan/atau menyelesaikan program pendidikan di 1TB.",]
    ],
    [
        r".*(berapa lama|maksimal|batas waktu).*asrama.*",
        ["Mahasiswa dapat menghuni Asrama Mahasiswa ITB sebagai tempat tinggal sementara untuk jangka waktu maksimal 1 tahun. Perpanjangan masa huni hanya dapat diberikan atas persetujuan unit kerja terkait berdasarkan usulan tertulis dan rekomendasi.",]
    ],
    [
        r".* maaf .*",
        ["Tidak apa-apa...",]
    ],
    # [
    #     r"I am fine",
    #     ["Great to hear that, How can I help you?",]
    # ],
    # [
    #     r"i'm (.*) doing good",
    #     ["Nice to hear that","How can I help you?:)",]
    # ],
    # [
    #     r"(.*) age?",
    #     ["I'm a computer program duden. Seriously you are asking me this?",]
    # ],
    # [
    #     r"what (.*) want ?",
    #     ["Make me an offer I can't refuse",]
    # ],
    # [
    #     r"how (.*) health(.*)",
    #     ["I'm a computer program, so I'm always healthy ",]
    # ],
    [
        r".*(kategori penghargaan|penghargaan).*",
        ["Terdapat 4 kategori penghargaan yang diberikan oleh ITB, yaitu Ganesha Perkasa untuk bidang olahraga , Ganesha Rasa untuk bidang seni, budaya, dan agama , Ganesha Karsa untuk bidang ilmiah dan sosial kemasyarakatan , serta Ganesha Karya untuk bidang karya inovatif.", "Berikut adalah 4 kategori utama penghargaan bagi mahasiswa ITB:\n"
        "- Ganesha Perkasa: untuk prestasi di bidang olahraga.\n"
        "- Ganesha Rasa: untuk prestasi di bidang seni, budaya, dan agama.\n"
        "- Ganesha Karsa: untuk prestasi di bidang ilmiah dan sosial kemasyarakatan.\n"
        "- Ganesha Karya: untuk prestasi di bidang karya inovatif.",]
    ],
    [
        r".*(jenis organisasi|organisasi kemahasiswaan|organisasi).*",
        ["Terdapat 4 jenis organisasi yang ada di ITB yaitu Keluarga Mahasiswa ITB (tingkat pusat), Unit Kegiatan Mahasiswa (UKM), Himpunan Mahasiswa Fakultas/Sekolah, dan Himpunan Mahasiswa Program Studi.", "Terdapat 4 jenis organisasi yang ada di ITB yaitu:\n"
        "- Keluarga Mahasiswa ITB (tingkat pusat)\n"
        "- Unit Kegiatan Mahasiswa (UKM)\n"
        "- Himpunan Mahasiswa Fakultas/Sekolah\n"
        "- Himpunan Mahasiswa Program Studi",]
    ],
    [
        r".*prosedur.*(bimbingan dan konseling|bk).*",
        ["Layanan bimbingan dan konseling diberikan atas permintaan mahasiswa yang bersangkutan atau berdasarkan rekomendasi pihak terkait. Layanan ini dapat dilakukan secara luring (offline) di lingkungan kampus pada jam kerja, maupun secara daring (online).",]
    ],
    [
        r".*syarat.*mahasiswa berprestasi.*",
        ["Syarat umum Mahasiswa Berprestasi tingkat Sarjana yaitu maksimal semester 6, usia ≤ 22 tahun, IP tinggi, prestasi nasional/internasional, tidak pernah melanggar aturan.", "Berikut adalah syarat umum Mahasiswa Berprestasi tingkat Sarjana:\n"
        "- Maksimal semester 6\n"
        "- Usia ≤ 22 tahun\n"
        "- IP tinggi\n"
        "- Prestasi nasional/internasional\n"
        "- Tidak pernah melanggar aturan",]
    ],
    [
        r".*syarat.*mendirikan.*(ukm|unit kegiatan mahasiswa).*",
        ["Untuk mengusulkan pendirian Unit Kegiatan Mahasiswa (UKM), diperlukan calon anggota sekurang-kurangnya 100 orang mahasiswa ITB. Calon anggota tersebut harus berasal dari minimal 3 (tiga) Program Studi dari Fakultas atau Sekolah yang berbeda.",]
    ],
    [
        r".*siapa.*(memberikan|memberi|ngasih).*izin.*kegiatan.*",
        ["Izin untuk kegiatan kemahasiswaan di tingkat Program Studi atau tingkat Fakultas/Sekolah diberikan secara resmi oleh Dekan. Pemberian izin tersebut tetap dikoordinasikan dengan unit kerja ITB yang menangani urusan kemahasiswaan.",]
    ],
    [
        r".*(non-tpb|non tpb|bukan tpb).*tinggal di asrama.*",
        ["Bisa, tetapi harus mendapat persetujuan unit terkait serta memenuhi persyaratan administratif.", "Bisa yaa, tapi kamu harus mendapat persetujuan unit terkait dan harus memenuhi persyaratan administratif."]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
]

# Create a chatbot
chatbot = Chat(patterns, reflections)

def main():
    print("Halo! Aku chatbot Peraturan Kemahasiswaan ITB. Yuk tanya aku kalau kamu bingung soal aturan kampus.\nKetik 'quit' untuk keluar.")
    while True:
        user_input = input("You: ")
        response = chatbot.respond(user_input)
        print("Bot:", response)
        if user_input.lower() == 'quit':
            break

if __name__ == "__main__":
    main()
# Out:
# Halo! Aku chatbot Peraturan Kemahasiswaan ITB.
# Yuk tanya aku kalau kamu bingung soal aturan kampus.
# Ketik 'quit' untuk keluar.
# Bot: Berikut adalah jenis layanan kemahasiswaan yang ada di ITB:
# a. Penyaluran Beasiswa dan/atau Bantuan Biaya Pendidikan;
# b. Asrarna Mahasiswa;
# c. Program Layanan Kesehatan Mahasiswa;
# d. Bimbingan dan Konseling;
# e. Pelatihan dan Pengembangan Karakter;
# f. Pengembangan Keprofesian dan Kewirausahaan Mahasiswa;
# g. Layanan Kegiatan Kemahasiswaan;
# h. Layanan bagi mahasiswa penyandang disabilitas.
# Bot: Berikut adalah jenis layanan kemahasiswaan yang ada di ITB:
# a. Penyaluran Beasiswa dan/atau Bantuan Biaya Pendidikan;
# b. Asrarna Mahasiswa;
# c. Program Layanan Kesehatan Mahasiswa;
# d. Bimbingan dan Konseling;
# e. Pelatihan dan Pengembangan Karakter;
# f. Pengembangan Keprofesian dan Kewirausahaan Mahasiswa;
# g. Layanan Kegiatan Kemahasiswaan;
# h. Layanan bagi mahasiswa penyandang disabilitas.
# Bot: Terdapat 2 jenis beasiswa yang dapat diberikan oleh ITB yakni beasiswa prestasi dan beasiswa ekonomi, beasiswa tersebut dapat mencakup bantuan biaya kuliah, bantuan biaya tugas akhir, bantuan biaya hidup dan/atau bentuk lain untuk membantu mahasiswa dalam mengikuti dan/atau menyelesaikan program pendidikan di 1TB.
# Bot: Mahasiswa dapat menghuni Asrama Mahasiswa ITB sebagai tempat tinggal sementara untuk jangka waktu maksimal 1 tahun. Perpanjangan masa huni hanya dapat diberikan atas persetujuan unit kerja terkait berdasarkan usulan tertulis dan rekomendasi.
# Bot: None
# Bot: None
# Bot: None
# Bot: Terdapat 4 kategori penghargaan yang diberikan oleh ITB, yaitu Ganesha Perkasa untuk bidang olahraga , Ganesha Rasa untuk bidang seni, budaya, dan agama , Ganesha Karsa untuk bidang ilmiah dan sosial kemasyarakatan , serta Ganesha Karya untuk bidang karya inovatif.
# Bot: Terdapat 4 jenis organisasi yang ada di ITB yaitu Keluarga Mahasiswa ITB (tingkat pusat), Unit Kegiatan Mahasiswa (UKM), Himpunan Mahasiswa Fakultas/Sekolah, dan Himpunan Mahasiswa Program Studi.
# Bot: Layanan bimbingan dan konseling diberikan atas permintaan mahasiswa yang bersangkutan atau berdasarkan rekomendasi pihak terkait. Layanan ini dapat dilakukan secara luring (offline) di lingkungan kampus pada jam kerja, maupun secara daring (online).
# Bot: Layanan bimbingan dan konseling diberikan atas permintaan mahasiswa yang bersangkutan atau berdasarkan rekomendasi pihak terkait. Layanan ini dapat dilakukan secara luring (offline) di lingkungan kampus pada jam kerja, maupun secara daring (online).
# Bot: Berikut adalah syarat umum Mahasiswa Berprestasi tingkat Sarjana:
# - Maksimal semester 6
# - Usia ≤ 22 tahun
# - IP tinggi
# - Prestasi nasional/internasional
# - Tidak pernah melanggar aturan
# Bot: Untuk mengusulkan pendirian Unit Kegiatan Mahasiswa (UKM), diperlukan calon anggota sekurang-kurangnya 100 orang mahasiswa ITB. Calon anggota tersebut harus berasal dari minimal 3 (tiga) Program Studi dari Fakultas atau Sekolah yang berbeda.
# Bot: None
# Bot: None
# Bot: Izin untuk kegiatan kemahasiswaan di tingkat Program Studi atau tingkat Fakultas/Sekolah diberikan secara resmi oleh Dekan. Pemberian izin tersebut tetap dikoordinasikan dengan unit kerja ITB yang menangani urusan kemahasiswaan.
# Bot: Bisa, tetapi harus mendapat persetujuan unit terkait serta memenuhi persyaratan administratif.
# Bot: Bisa, tetapi harus mendapat persetujuan unit terkait serta memenuhi persyaratan administratif.

# %%
print(reflections)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(reflections)
#
# NameError: name 'reflections' is not defined

# %% [markdown]
# ## Chatbot WITH LLM

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

MODEL_ID = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

# Load
tok = AutoTokenizer.from_pretrained(MODEL_ID)
pipe = pipeline(
    "text-generation",
    model=AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        torch_dtype="auto",
        device_map="auto"
    ),
    tokenizer=tok
)

def chat_once(user_msg: str) -> str:
    messages = [
        {"role": "system", "content": "You are an assistant who helps for medical"},
        {"role": "user", "content": user_msg},
    ]
    prompt = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

    out = pipe(
        prompt,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        eos_token_id=tok.eos_token_id,
    )[0]["generated_text"]

    reply = out[len(prompt):].strip()
    return reply

if __name__ == "__main__":
    print("HF Chatbot (TinyLlama). ketik 'exit' untuk keluar.")
    while True:
        u = input("You: ")
        if u.strip().lower() == "exit":
            break
        print("Bot:", chat_once(u))
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Downloading tokenizer_config.json: 0.00B [00:00, ?B/s]
# c:\Users\Kenlyn\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Kenlyn\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File c:\Users\Kenlyn\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\models\llama\tokenization_llama_fast.py:29
#      27     from transformers.pipelines.conversational import Conversation
# ---> 29 require_version("tokenizers>=0.13.3")
#      31 if is_sentencepiece_available():
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\utils\versions.py:111, in require_version(requirement, hint)
#     110 for op, want_ver in wanted.items():
# --> 111     _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\utils\versions.py:44, in _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#      43 if not ops[op](version.parse(got_ver), version.parse(want_ver)):
# ---> 44     raise ImportError(
#      45         f"{requirement} is required for a normal functioning of this module, but found {pkg}=={got_ver}.{hint}"
#      46     )
#
# ImportError: tokenizers>=0.13.3 is required for a normal functioning of this module, but found tokenizers==0.13.2.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 6
#       3 MODEL_ID = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
#       5 # Load
# ----> 6 tok = AutoTokenizer.from_pretrained(MODEL_ID)
#       7 pipe = pipeline(
#       8     "text-generation",
#       9     model=AutoModelForCausalLM.from_pretrained(
#    (...)
#      14     tokenizer=tok
#      15 )
#      17 def chat_once(user_msg: str) -> str:
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\models\auto\tokenization_auto.py:719, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     717 if use_fast and not config_tokenizer_class.endswith("Fast"):
#     718     tokenizer_class_candidate = f"{config_tokenizer_class}Fast"
# --> 719     tokenizer_class = tokenizer_class_from_name(tokenizer_class_candidate)
#     720 if tokenizer_class is None:
#     721     tokenizer_class_candidate = config_tokenizer_class
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\models\auto\tokenization_auto.py:409, in tokenizer_class_from_name(class_name)
#     407 module = importlib.import_module(f".{module_name}", "transformers.models")
#     408 try:
# --> 409     return getattr(module, class_name)
#     410 except AttributeError:
#     411     continue
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1120, in _LazyModule.__getattr__(self, name)
#    1118     value = self._get_module(name)
#    1119 elif name in self._class_to_module.keys():
# -> 1120     module = self._get_module(self._class_to_module[name])
#    1121     value = getattr(module, name)
#    1122 else:
#
# File c:\Users\Kenlyn\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1132, in _LazyModule._get_module(self, module_name)
#    1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
# -> 1132     raise RuntimeError(
#    1133         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1134         f" traceback):\n{e}"
#    1135     ) from e
#
# RuntimeError: Failed to import transformers.models.llama.tokenization_llama_fast because of the following error (look up to see its traceback):
# tokenizers>=0.13.3 is required for a normal functioning of this module, but found tokenizers==0.13.2.

# %% [markdown]
# # Chatbot RAG -LLM
#
# Chatbot ini menggunakan dokumen PDF cerita fiksi “Sepuluh Sahabat ke Kota Senja”.
# Secara garis besar, alurnya sebagai berikut:
#
# 1. Parsing PDF  → Ekstraksi teks halaman memakai pypdf.PdfReader. Teks dibersihkan (ligature, soft-hyphen, pemotongan “-\n”, spasi berlebih). Dokumen kemudian dipecah berdasarkan heading bernomor (jika ada); bila tidak terdeteksi, dipotong per ukuran tetap (default chunk_size=1200, overlap=200).
#
#
# 2. Struktur & Booster Domain Cerita → Konten diperkaya dengan booster pencarian untuk kode & istilah cerita:
# C01–C10 (karakter), L01–L10 (lokasi), S1–S8 (adegan), K1–K4 (konflik), T01/T02 (tiket), R01/R02 (nota), P01 (peta), nama tokoh/lokasi (Aksa, Bela, Museum Riwayat Batu, Alun-Alun, Gedung Pusaka Angin, Danau Cermin, Pasar Malam Senja, Rumah Makan Panyawara, Terminal Caraka), serta jam penting 07:30, 09:00, 13:00. Booster ini meningkatkan skor kandidat yang relevan saat retrieve.
#
# 3. Embedding & Indexing (RAG) → Potongan teks diubah menjadi vektor menggunakan SentenceTransformer (BAAI/bge-m3) dengan normalisasi, lalu diindeks ke FAISS (IndexFlatIP) untuk semantic search. Parameter utama: k=12 untuk pencarian awal (top-k).
#
# 4. Re-ranking (opsional) → Hasil retrieve awal dapat diurut ulang oleh CrossEncoder (BAAI/bge-reranker-v2-m3) agar konteks paling relevan naik ke atas (default topk_final=6). Fitur ini bisa dimatikan lewat konfigurasi jika RAM terbatas.
#
# 5. LLM Generation → Jawaban disintesis oleh Qwen/Qwen2.5-1.5B-Instruct. Prompt dibentuk di fungsi make_messages, menegaskan aturan: jawab singkat, jelas, dan HANYA dari konteks. Jika tidak ada informasi relevan, bot menjawab: “Tidak ditemukan dalam naskah.” (tanpa menyertakan rujukan).
#
# Fungsi kunci:
#
# build_docs() → baca PDF, bersihkan teks, pecah jadi potongan.
# retrieve() → FAISS search + booster kode/istilah cerita (+ opsional re-ranking).
# make_messages() → susun prompt berisi konteks terpilih.
# generate_answer() → panggil LLM untuk menghasilkan jawaban.
# chat(query) → pipeline ujung-ke-ujung (retrieve → generate).

# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.0.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-6.0.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-6.0.0

# %%
pip install -U faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 36.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
# Cell 1 - Import libraries
import os, re, textwrap
from dataclasses import dataclass
from typing import List, Dict, Tuple
import numpy as np

from pypdf import PdfReader  # ekstraksi teks PDF berbasis teks

import faiss
from sentence_transformers import SentenceTransformer, CrossEncoder  # biarkan jika pakai re-ranking

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

print("Libraries diimport")
# Out:
# Libraries diimport

# %%
# Cell 2 - Setup PDF reader (Colab) — PDF-only tanpa OCR
import os, re
from pypdf import PdfReader

# Ganti ke path PDF kamu di Colab
PDF_PATH = "/content/Sepuluh Sahabat ke Kota Senja.pdf"

def verify_pdf(path: str) -> bool:
    if not os.path.isfile(path):
        raise FileNotFoundError(f"Tidak menemukan PDF di: {path}")
    try:
        reader = PdfReader(path)
        n_pages = len(reader.pages)
        if n_pages == 0:
            raise ValueError("PDF tidak memiliki halaman.")
        print(f"PDF OK — jumlah halaman: {n_pages}")
        return True
    except Exception as e:
        raise RuntimeError(f"Gagal membaca PDF: {e}")

def extract_pages(path: str):
    """Ekstrak teks per halaman (tanpa OCR). Halaman kosong di-skip."""
    reader = PdfReader(path)
    pages = []
    for i, page in enumerate(reader.pages, start=1):
        txt = page.extract_text() or ""
        # Normalisasi ringan
        txt = txt.replace("\u00ad", "")     # soft hyphen
        txt = txt.replace("-\n", "")        # sambung kata yang terpotong
        txt = re.sub(r"\s+", " ", txt).strip()
        if txt:
            pages.append({"page": i, "text": txt})
    print(f"Halaman dengan teks: {len(pages)}")
    return pages

# Verifikasi & contoh ekstraksi
verify_pdf(PDF_PATH)
pages_text = extract_pages(PDF_PATH)
if pages_text:
    print("Cuplikan halaman 1 (200 karakter):")
    print(pages_text[0]["text"][:200])
# Out:
# PDF OK — jumlah halaman: 2
# Halaman dengan teks: 2
# Cuplikan halaman 1 (200 karakter):
# Sepuluh Sahabat ke Kota Senja Ringkasan Sepuluh sahabat melakukan perjalanan sehari ke Kota Senja . Masing -masing memiliki peran berbeda (ketua, navigator, fotografer, bendahara, dll.). Mereka mengun

# %%
# Cell 3 - Test ekstraksi teks PDF
import os

def test_pdf_extraction(path=PDF_PATH, sample_chars=300, sample_pages=3):
    """Uji ekstraksi teks dari PDF berbasis teks (tanpa OCR)."""
    if not os.path.isfile(path):
        print(f"File tidak ditemukan: {path}")
        return []
    try:
        pages = extract_pages(path)  # pakai fungsi dari Cell 2
    except Exception as e:
        print(f"Gagal ekstrak: {e}")
        return []

    n = len(pages)
    print(f"Total halaman dengan teks: {n}")
    if n == 0:
        print("Peringatan: Tidak ada teks terdeteksi. PDF kemungkinan berbasis gambar (butuh OCR).")
        return pages

    # Tampilkan cuplikan beberapa halaman awal
    for i, p in enumerate(pages[:sample_pages], start=1):
        txt = p["text"]
        print(f"\n[Hal {p['page']}] {len(txt)} karakter")
        print(txt[:sample_chars])

    return pages

# Jalankan uji
pages_text = test_pdf_extraction(PDF_PATH)
# Out:
# Halaman dengan teks: 2
# Total halaman dengan teks: 2
#
# [Hal 1] 1646 karakter
# Sepuluh Sahabat ke Kota Senja Ringkasan Sepuluh sahabat melakukan perjalanan sehari ke Kota Senja . Masing -masing memiliki peran berbeda (ketua, navigator, fotografer, bendahara, dll.). Mereka mengunjungi beberapa lokasi berkode L01–L08, membawa artefak (tiket/nota/peta, berkode Txx/Rxx/Pxx), dan m
#
# [Hal 2] 1572 karakter
# Artefak: T01 (tiket bus L01→L02), T02 (tiket museum L02, 10 lembar, dipegang C08), R01 (nota sarapan 07:40), R02 (nota makan siang L08), P01 (peta rute utama: L01→L02→L03→L04→L08→L06→L07→L10). 3) Itinerary & Kronologi (Perkiraan, rombongan bergerak lambat) • 07:30 — Kumpul di L01; cek kehadiran, bag

# %%
# Cell 4 - PDF processing (tanpa OCR)

def clean_text(s: str) -> str:
    """Bersihkan teks dari karakter aneh & normalisasi spasi/baris."""
    s = (s or "")
    s = s.replace("\x00", " ").replace("\ufb01", "fi").replace("\ufb02", "fl")  # ligatures umum
    s = s.replace("\u00ad", "")        # soft hyphen
    s = s.replace("-\n", "")           # sambung kata terpotong di line break
    s = re.sub(r"\n{3,}", "\n\n", s)   # kompres newline berlebih
    s = re.sub(r"[ \t]+", " ", s)      # kompres spasi/tab
    return s.strip()

def read_pdf_text(path: str, min_chars: int = 50) -> Tuple[str, List[Tuple[int, str]]]:
    print(f"Membaca PDF: {os.path.basename(path)}")

    reader = PdfReader(path)
    pages: List[Tuple[int, str]] = []

    for i, p in enumerate(reader.pages, start=1):
        raw = p.extract_text() or ""
        t = clean_text(raw)
        pages.append((i, t))
        print(f"  Halaman {i}: {len(t)} karakter")

    # Peringatan untuk halaman yang tampak kosong/scan
    suspect = [i for (i, t) in pages if len(t) < min_chars]
    if suspect:
        print(f"Peringatan: {len(suspect)} halaman terdeteksi minim teks {suspect}. "
              f"Kemungkinan berbasis gambar. Mode ini PDF-only, OCR dinonaktifkan.")

    full = "\n\n".join([f"[page {i}]\n{t}" for i, t in pages])
    total_chars = sum(len(t) for _, t in pages)
    print(f"Total: {len(pages)} halaman, {total_chars} karakter (tanpa OCR)")

    return full, pages

# Contoh pakai (opsional):
full_text, pages_list = read_pdf_text(PDF_PATH)
print(full_text[:500])
# Out:
# Membaca PDF: Sepuluh Sahabat ke Kota Senja.pdf
#   Halaman 1: 1672 karakter
#   Halaman 2: 1597 karakter
# Total: 2 halaman, 3269 karakter (tanpa OCR)
# [page 1]
# Sepuluh Sahabat ke Kota Senja
# Ringkasan
# Sepuluh sahabat melakukan perjalanan sehari ke Kota Senja . Masing -masing memiliki peran
# berbeda (ketua, navigator, fotografer, bendahara, dll.). Mereka mengunjungi beberapa lokasi
# berkode L01–L08, membawa artefak (tiket/nota/peta, berkode Txx/Rxx/Pxx), dan menghadapi
# insiden kecil yang terselesaikan secara kolaboratif. Naskah ini singkat, berstruktur, dan konsisten
# untuk memudahkan Retrieval-Augmented Generation (RAG).
# 1) Karakter (C01–C1

# %%
# Cell 5 - Path file PDF (PDF-only)
import os

# Ganti ke path PDF kamu (Colab / local)
PDF_PATH = "/content/Sepuluh Sahabat ke Kota Senja.pdf"  # ubah jika perlu

def set_pdf_list(path: str):
    if os.path.isfile(path):
        print(f"File PDF ditemukan: {os.path.basename(path)}")
        return [path]
    else:
        print(f"File tidak ditemukan: {path}")
        print("Pastikan path file sudah benar.")
        return []

PDFS = set_pdf_list(PDF_PATH)
# Out:
# File PDF ditemukan: Sepuluh Sahabat ke Kota Senja.pdf

# %%
# Cell 6 - Load & proses dokumen PDF (Kota Senja, PDF-only)
import re, os

all_docs = []

# Pola regex sesuai struktur naskah "Kota Senja"
# 1) Heading bernomor: "1. Daftar Karakter (C01–C10)", "2. Daftar Lokasi (L01–L10)", dst.
RE_HEADING_NUM = re.compile(
    r'(?m)^\s*(\d{1,2}\.\s+[^\n]+)\s*\n(.*?)(?=^\s*\d{1,2}\.\s+[^\n]+|\Z)',
    flags=re.DOTALL

)

# 2) Adegan: "S1 — Titik Kumpul di L01", "S2 — Perjalanan ke L02", dst.
#    Mendukung variasi dash: -, –, —
RE_SCENE = re.compile(
    r'(?m)^\s*(S\d{1,2}\s*[—\-–]\s*[^\n]+)\s*\n(.*?)(?=^\s*S\d{1,2}\s*[—\-–]\s*[^\n]+|\Z)',
    flags=re.DOTALL
)

# 3) Q–A: baris yang diawali "Q:" lalu diikuti "A:" (bisa berulang)
RE_QA_PAIR = re.compile(
    r'(?m)^\s*Q\s*:\s*(.+?)\s*\n\s*A\s*:\s*(.+?)(?=\n\s*Q\s*:|\Z)',
    flags=re.DOTALL
)

for path in PDFS:
    print(f"\n=== Proses: {os.path.basename(path)} ===")
    full_text, page_texts = read_pdf_text(path)  # fungsi dari Cell 4
    source_name = os.path.basename(path)
    before_count = len(all_docs)

    # 1) Ekstrak per heading bernomor
    for m in RE_HEADING_NUM.finditer(full_text):
        title = m.group(1).strip()
        body  = (m.group(2) or "").strip()

        # hint halaman: cari kemunculan judul
        page_hint = None
        pat = re.escape(title)
        for (pg, txt) in page_texts:
            if re.search(pat, txt, flags=re.IGNORECASE):
                page_hint = pg
                break

        all_docs.append({
            "text": f"{title}\n{body}",
            "section": title,
            "source": source_name,
            "page_hint": page_hint
        })

    # 2) Ekstrak Adegan Sx — ... (potongan lebih granular)
    for m in RE_SCENE.finditer(full_text):
        title = m.group(1).strip()      # contoh: "S3 — Museum L02 (09:00–10:00)"
        body  = (m.group(2) or "").strip()

        # hint halaman: cukup cari "S\d+"-nya
        page_hint = None
        s_code = re.match(r'^\s*(S\d{1,2})', title)
        if s_code:
            s_pat = re.escape(s_code.group(1))
            for (pg, txt) in page_texts:
                if re.search(rf'\b{s_pat}\b', txt):
                    page_hint = pg
                    break

        all_docs.append({
            "text": f"{title}\n{body}",
            "section": title,            # simpan judul adegan sebagai section
            "source": source_name,
            "page_hint": page_hint
        })

    # 3) Ekstrak Q–A (berguna untuk retrieval pertanyaan langsung)
    for m in RE_QA_PAIR.finditer(full_text):
        q = m.group(1).strip()
        a = m.group(2).strip()
        qa_text = f"Q: {q}\nA: {a}"
        all_docs.append({
            "text": qa_text,
            "section": "Q-A",
            "source": source_name,
            "page_hint": None
        })

    # 4) Fallback: jika tidak ada potongan yang berhasil ditambahkan dari file ini,
    #    gunakan chunking ukuran tetap
    after_count = len(all_docs)
    if after_count == before_count:
        print("Pola heading/adegan/Q-A tidak ditemukan. Menggunakan fallback chunking...")
        step = 1200
        for i in range(0, len(full_text), step):
            chunk = full_text[i:i+step].strip()
            if not chunk:
                continue
            all_docs.append({
                "text": chunk,
                "section": "CHUNK",
                "source": source_name,
                "page_hint": None
            })

print("chunks:", len(all_docs))
# Out:
# === Proses: Sepuluh Sahabat ke Kota Senja.pdf ===
# Membaca PDF: Sepuluh Sahabat ke Kota Senja.pdf
#   Halaman 1: 1672 karakter
#   Halaman 2: 1597 karakter
# Total: 2 halaman, 3269 karakter (tanpa OCR)
# Pola heading/adegan/Q-A tidak ditemukan. Menggunakan fallback chunking...
# chunks: 3

# %%
# Cell 7 - Setup embedding & FAISS index (PDF-only)
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss

if not all_docs:
    raise ValueError("Tidak ada dokumen untuk di-embed. Pastikan Cell 6 menghasilkan 'all_docs' > 0.")

EMB_MODEL = "BAAI/bge-m3"
print(f"Memuat embedding model: {EMB_MODEL}")
embedder = SentenceTransformer(EMB_MODEL)

corpus = [d["text"] for d in all_docs]
print(f"Jumlah chunk untuk di-embed: {len(corpus)}")

# Encode ke vektor (cosine via normalize_embeddings=True → pakai IndexFlatIP)
X = embedder.encode(
    corpus,
    batch_size=64,
    normalize_embeddings=True,
    show_progress_bar=True
)
X = np.array(X, dtype="float32")

print("Membangun FAISS index (Inner Product / Cosine-normalized)...")
index = faiss.IndexFlatIP(X.shape[1])
index.add(X)

print(f"Index siap. Dimensi: {X.shape[1]}, Jumlah vektor: {index.ntotal}")
# Out:
# Memuat embedding model: BAAI/bge-m3
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# Jumlah chunk untuk di-embed: 3
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Membangun FAISS index (Inner Product / Cosine-normalized)...
# Index siap. Dimensi: 1024, Jumlah vektor: 3

# %%
# Cell 8 - Setup reranker (opsional tapi disarankan)
from sentence_transformers import CrossEncoder
import numpy as np

RERANKER = "BAAI/bge-reranker-v2-m3"
print(f"Memuat reranker: {RERANKER}")
reranker = CrossEncoder(RERANKER)  # otomatis pakai GPU jika tersedia (via torch)

def rerank_pairs(query: str, docs: List[Dict], topk: int = 5) -> List[Dict]:
    """
    Re-ranking doc hasil retrieval awal (mis. dari FAISS) dengan CrossEncoder.
    Mengembalikan hingga topk dokumen terbaik, menambahkan 'rerank_score'.
    """
    if not docs:
        return []
    k = min(topk, len(docs))
    pairs = [[query, d["text"]] for d in docs]
    scores = np.asarray(reranker.predict(pairs), dtype="float32")
    order = np.argsort(-scores)[:k]
    return [docs[i] | {"rerank_score": float(scores[i])} for i in order]
# Out:
# Memuat reranker: BAAI/bge-reranker-v2-m3
# config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]

# %%
# Cell 9 - Setup LLM
LLM = "Qwen/Qwen2.5-1.5B-Instruct"

device = "cuda" if torch.cuda.is_available() else "cpu"
tokenizer = AutoTokenizer.from_pretrained(LLM, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(
    LLM,
    torch_dtype=torch.float16 if device == "cuda" else torch.float32,
    low_cpu_mem_usage=True,
)
model.to(device)
model.eval()

def make_messages(query: str, ctxs: List[Dict]) -> List[Dict]:
    bullets = []
    for c in ctxs:
        snippet = re.sub(r"\s{2,}", " ", c["text"]).strip()[:900]
        bullets.append(f"- {snippet}")
    context_block = "\n".join(bullets) if bullets else "(konteks kosong)"
    return [
        {
            "role": "system",
            "content": (
                "Anda asisten akademik yang menjawab berdasarkan konteks yang diberikan. "
                "Jawab SINGKAT, JELAS, dan HANYA dari konteks. "
                "Jika tidak ada informasi relevan, balas: 'Tidak ditemukan dalam dokumen.' "
                "Jangan sertakan rujukan/sumber dalam jawaban."
            ),
        },
        {
            "role": "user",
            "content": (
                f"KONTEKS:\n{context_block}\n\n"
                f"PERTANYAAN:\n{query}\n\n"
                f"Jawab singkat dan jelas tanpa menyertakan rujukan."
            ),
        },
    ]

@torch.inference_mode()
def generate_answer(messages, max_new_tokens=256):
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    input_len = inputs["input_ids"].shape[1]
    out = model.generate(
        **inputs,
        do_sample=False,
        max_new_tokens=max_new_tokens,
        pad_token_id=tokenizer.eos_token_id,
        eos_token_id=tokenizer.eos_token_id,
    )[0]
    gen = out[input_len:]
    txt = tokenizer.decode(gen, skip_special_tokens=True).strip()
    return re.sub(r"^assistant\s*:\s*", "", txt, flags=re.I) or "Tidak ditemukan dalam dokumen."
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
# Cell 10 - Retrieval & Chat khusus cerita "Kota Senja"

from dataclasses import dataclass
from typing import List, Dict, Optional
import numpy as np
import re, os

@dataclass
class Retrieved:
    text: str
    score: float
    section: str
    source: str
    page_hint: Optional[int]

# --- Booster domain "Kota Senja" ---
# Pola kode: C01–C10, L01–L10, S1–S8, K1–K4, T01/T02, R01/R02, P01
PAT_CODE = re.compile(r"\b((?:C|L|S|K|T|R|P)\d{1,2})\b", re.IGNORECASE)

# Nama karakter & lokasi utama + istilah perjalanan dari naskah
STORY_TERMS = (
    r"(Aksa|Bela|Ciko|Dira|Eka|Fajar|Gita|Hani|Iwan|Juno|"
    r"Stasiun Mentari|Museum Riwayat Batu|Alun-?Alun( Kota Senja)?|Gedung Pusaka Angin|"
    r"Danau Cermin|Pasar Malam Senja|Rumah Makan Panyawara|Terminal Caraka|Kota Senja|"
    r"timekeeper|P3K|artefak|tiket|nota|peta|buffer waktu|itinerary|timeline|sesi foto|"
    r"07:30|09:00|13:00)"
)

IMPORTANT_TERMS = rf"({STORY_TERMS}|{PAT_CODE.pattern})"

def _boost_ids_from_query(query: str) -> List[int]:
    """Ambil doc yang mengandung kode (Cxx/Lxx/Sx/Kx/Txx/Rxx/Pxx) atau nama penting dari query."""
    boost_ids: List[int] = []
    if not query:
        return boost_ids

    # Kode eksplisit dalam query (mis. 'L02', 'C04', 'R02')
    codes = set(m.group(1).upper() for m in PAT_CODE.finditer(query))

    # Nama/keyword penting (huruf besar untuk pencocokan case-insensitive)
    names = [
        "AKSA","BELA","CIKO","DIRA","EKA","FAJAR","GITA","HANI","IWAN","JUNO",
        "STASIUN MENTARI","MUSEUM RIWAYAT BATU","ALUN","GEDUNG PUSAKA ANGIN",
        "DANAU CERMIN","PASAR MALAM SENJA","RUMAH MAKAN PANYAWARA","TERMINAL CARAKA","KOTA SENJA",
        "07:30","09:00","13:00"
    ]

    for i, d in enumerate(all_docs):
        sec = (d.get("section") or "")
        txt = (d.get("text") or "")
        hit = False
        for c in codes:
            if re.search(rf"\b{re.escape(c)}\b", sec, flags=re.I) or re.search(rf"\b{re.escape(c)}\b", txt, flags=re.I):
                hit = True; break
        if not hit:
            for nm in names:
                if re.search(nm, sec, flags=re.I) or re.search(nm, txt, flags=re.I):
                    hit = True; break
        if hit:
            boost_ids.append(i)
    return boost_ids

def make_messages_story(query: str, ctxs: List[Dict]) -> List[Dict]:
    """Template pesan untuk LLM yang menjawab soal cerita 'Kota Senja'."""
    bullets = []
    for c in ctxs:
        snippet = re.sub(r"\s{2,}", " ", c["text"]).strip()[:900]
        bullets.append(f"- {snippet}")
    context_block = "\n".join(bullets) if bullets else "(konteks kosong)"
    return [
        {
            "role": "system",
            "content": (
                "Anda adalah asisten untuk cerita fiksi 'Sepuluh Sahabat ke Kota Senja'. "
                "Jawab SINGKAT, JELAS, dan HANYA berdasarkan konteks. "
                "Jika tidak ada informasi relevan di konteks, balas: 'Tidak ditemukan dalam naskah.' "
                "Jangan menambahkan rujukan/sumber dalam jawaban."
            ),
        },
        {
            "role": "user",
            "content": (
                f"KONTEKS:\n{context_block}\n\n"
                f"PERTANYAAN:\n{query}\n\n"
                f"Jawab singkat dan jelas tanpa menyertakan rujukan."
            ),
        },
    ]

def retrieve(query: str, k: int = 12, topk_final: int = 6) -> List[Retrieved]:
    # 1) Booster dari kode/nama pada query
    bonus_ids = _boost_ids_from_query(query)

    # 2) Semantic top-k via FAISS
    qv = np.array(embedder.encode([query], normalize_embeddings=True), dtype="float32")
    D, I = index.search(qv, min(k, index.ntotal))
    I = I[0].tolist(); D = D[0].tolist()

    # 3) Gabungkan kandidat + skor awal
    cand, seen = [], set()
    for bid in bonus_ids + I:
        if bid in seen:
            continue
        seen.add(bid)
        d = all_docs[bid]
        base = D[I.index(bid)] if bid in I else 0.0
        sc = base
        if bid in bonus_ids:
            sc += 0.12  # bonus untuk kecocokan kode/nama dari query
        if re.search(IMPORTANT_TERMS, d["text"], flags=re.I):
            sc += 0.05  # bonus ringan untuk istilah penting naskah
        cand.append(d | {"score": float(sc)})

    if not cand:
        return []

    # 4) Re-rank (CrossEncoder) → ambil topk_final
    reranked = rerank_pairs(query, cand, topk=topk_final)
    out: List[Retrieved] = []
    for c in reranked:
        out.append(Retrieved(
            text=c["text"],
            score=float(c.get("rerank_score", c.get("score", 0.0))),
            section=c["section"],
            source=c["source"],
            page_hint=c["page_hint"]
        ))
    return out

def chat(query: str) -> Dict:
    ctxs = retrieve(query)
    msgs = make_messages_story(query, [c.__dict__ for c in ctxs])
    ans = generate_answer(msgs)
    cites = [{"section": c.section, "page_hint": c.page_hint, "source": c.source} for c in ctxs]
    if ans.strip().lower() == (query or "").strip().lower():
        ans = "Tidak ditemukan dalam naskah."
    return {"answer": ans, "contexts": cites}

print("="*60)
print("RAG 'Sepuluh Sahabat ke Kota Senja' — siap dipakai!")
print("="*60)
# Out:
# ============================================================
# RAG 'Sepuluh Sahabat ke Kota Senja' — siap dipakai!
# ============================================================

# %%
# Cell 11 - Chat interaktif

def start_chat(show_sources: bool = False):
    """Mulai chat interaktif untuk naskah 'Sepuluh Sahabat ke Kota Senja'."""
    print("CHATBOT 'Kota Senja' AKTIF!")
    print("Tanya apa saja tentang naskah 'Sepuluh Sahabat ke Kota Senja'.")
    print("Ketik 'exit' untuk keluar.")
    print("="*50)

    while True:
        try:
            q = input("\nAnda: ").strip()
        except EOFError:
            print("\nSesi dihentikan.")
            break

        if not q or q.lower() in {"exit", "quit", "q"}:
            print("Terima kasih!")
            break

        out = chat(q)
        print(f"\nBot: {out['answer']}")

        if show_sources and out.get("contexts"):
            print("\n[Sumber konteks]")
            for i, c in enumerate(out["contexts"], start=1):
                sec = c.get("section") or "—"
                pg  = c.get("page_hint")
                src = c.get("source") or ""
                pg_str = f"hal {pg}" if pg else "hal ?"
                print(f"{i}. {sec} ({pg_str}, {src})")

        print("-" * 50)

if __name__ == "__main__":
    # Ubah ke True jika ingin melihat sumber konteks yang dipakai
    start_chat(show_sources=False)
# Out:
# CHATBOT 'Kota Senja' AKTIF!
# Tanya apa saja tentang naskah 'Sepuluh Sahabat ke Kota Senja'.
# Ketik 'exit' untuk keluar.
# ==================================================
#
# Anda: siapa ketua rombongan ?
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Bot: Aksa
# --------------------------------------------------
#
# Anda: bendahara siapa?
#
# Bot: Dira
# --------------------------------------------------
#
# Anda: Lokasi museum Museum Riwayat Batu  dimana dan buka jem berapa?
#
# Bot: Museum Riwayat Batu dimulai dari Lokasi 2 (L02) dan buka mulai pukul 09:00.
# --------------------------------------------------
#
# Anda: exit
# Terima kasih!
